# %% [markdown]
# <a href="https://colab.research.google.com/github/thkhz/Univercity/blob/main/practice%20/oop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6
# Out:
# (0.0, 0.0, 0.0)
# 0.5235987755982988
# False
# True
# 1.6

# %%
import math


class Sphere:
    def __init__(self, radius = 1.0, xcoordin = 0.0, ycoordin = 0.0, zcoordin = 0.0):
        self.radius = radius
        self.xcoordin = xcoordin
        self.ycoordin = ycoordin
        self.zcoordin = zcoordin

    def get_volume(self):
        return (4/3) * math.pi * (self.radius ** 3)

    def get_square(self):
        return 4 * math.pi * (self.radius ** 2)

    def get_radius(self):
        return self.radius

    def get_center(self):
        return (self.xcoordin, self.ycoordin, self.zcoordin)

    def set_radius(self, r):
        self.radius = r

    def set_center(self, x, y, z):
        self.xcoordin = x
        self.ycoordin = y
        self.zcoordin = z

    def is_point_inside(self, x, y, z):
        dist_sq = (x - self.xcoordin)**2 + (y - self.ycoordin)**2 + (z - self.zcoordin)**2
        return dist_sq <= self.radius**2

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
class SuperStr(str):
  def is_repeatance(self, s):
    if not isinstance(s, str):
      return False
    if not s:
      return False
    if len(self) == 0:
      return False
    n = len(self) // len(s)
    return s * n == self


  def is_palindrom(self):
    if not self:
      return True
    t = self.lower()
    return t == t[::-1]

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True
# Out:
# True
# True
# True
# False
# False
# False
# 123123123123
# 123123123123
# 123123123123qwe
# True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender, students, hw):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        self.onlecture = students
        self.hw = hw

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender', 23, 9)
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

class Lecturer(Mentor):
  pass

class Reviewer(Mentor):
  def __init__(self, name, surname, hw):
    super().__init__(name, surname)
    self.hw = hw

  def otchislenie(self, student, course, hw):
    self.hw = hw
    if self.hw < 5:
      return 'Необходимо сдать до завтра'
    else:
      return 'У вас все хорошо!'

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender', 23, 9)
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)

cool_Lecturer = Lecturer('Alex', 'Pit')
cool_Reviewer = Reviewer('James', 'Bound', 9)
norm_student = Student('Rick', 'David', 'Male', 2, 10)

cool_Lecturer.rate_hw(norm_student, 'Math', 15)


print("Оценки студента по курсам: ", norm_student.grades)
print(cool_Reviewer.otchislenie(best_student, 'Math', 4))
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}
# Оценки студента по курсам:  {'Math': [15]}
# Необходимо сдать до завтра

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
class Student:
    def __init__(self, name, surname, gender, students, homeworks):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        self.homeworks = homeworks

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


    def rate_lecturer(self, lecturer, course, grade):
        if course in lecturer.grades:
            lecturer.grades[course].append(grade)
        else:
            lecturer.grades[course] = [grade]
        return f"Оценка {grade} поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}."


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

class Lecturer(Mentor):
    def __init__(self, name, surname, students, lectures):
        super().__init__(name, surname)
        self.lectures = lectures
        self.grades = {}


class Reviewer(Mentor):
    def __init__(self, name, surname, homeworks=0):
        super().__init__(name, surname)
        self.homeworks = homeworks

    def rate_hw(self, student, course, grade):
        if course in student.grades:
            student.grades[course].append(grade)
        else:
            student.grades[course] = [grade]
        return f"Оценка {grade} поставлена студенту {student.name} {student.surname} за дз по курсу {course}."

# %%
student = Student('Rick', 'David', 'Male', 2, 10)
lecturer = Lecturer('Alex', 'Pit', 10, 3)
reviewer = Reviewer('James', 'Bound', 9)

student.courses_in_progress.append('Python')
lecturer.courses_attached.append('Python')
reviewer.courses_attached.append('Python')

print(reviewer.rate_hw(student, 'Python', 7))
print(student.rate_lecturer(lecturer, 'Python', 10))

print(student.grades)
print(lecturer.grades)
# Out:
# Оценка 7 поставлена студенту Rick David за дз по курсу Python.
# Оценка 10 поставлена лектору Alex Pit за курс Python.
# {'Python': [7]}
# {'Python': [10]}

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
class Student:
    def __init__(self, name, surname, gender, students=0, homeworks=0):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        self.homeworks = homeworks

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)
    def add_finished_course(self, course_name):
      self.finished_courses.append(course_name)


    def rate_lecturer(self, lecturer, course, grade):
        if course in lecturer.grades:
            lecturer.grades[course].append(grade)
        else:
            lecturer.grades[course] = [grade]
        return f"Оценка {grade} поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}."

    def _avg_grade(self):
        if not self.grades:
            return 0
        all_grades = [g for grades in self.grades.values() for g in grades]
        return sum(all_grades) / len(all_grades)

    def __str__(self):
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {self._avg_grade():.1f}\n"
                f"Курсы в процессе изучения: {', '.join(self.courses_in_progress)}\n"
                f"Завершенные курсы: {', '.join(self.finished_courses)}")




class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

class Lecturer(Mentor):
    def __init__(self, name, surname, students=0, lectures=0):
        super().__init__(name, surname)
        self.lectures = lectures
        self.grades = {}

    def __str__(self):
      sum_grade = 0.0
      if self.grades:
          all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
          if all_grades:
              sum_grade = sum(all_grades) / len(all_grades)

      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Средняя оценка за лекции: {sum_grade}')


class Reviewer(Mentor):
    def __init__(self, name, surname, homeworks=0):
        super().__init__(name, surname)
        self.homeworks = homeworks

    def rate_hw(self, student, course, gradest):
        if course in student.grades:
            student.grades[course].append(gradest)
        else:
            student.grades[course] = [gradest]
        return f"Оценка {gradest} успешно поставлена студенту {student.name} {student.surname} за домашнее задание по курсу {course}."

    def otchislenie(self, student, course, hw):
      self.hw = hw
      if self.hw < 5:
        return 'Необходимо сдать до завтра'
      else:
        return 'У вас все хорошо!'


    def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'

# %%
cool_student = Student('Rick', 'David', 'Male')
cool_student.courses_in_progress.append('Python')
cool_student.courses_in_progress.append('Math')
cool_student.add_finished_course('English')

cool_student.grades['Python'] = [1, 2, 9]
cool_student.grades['Math'] = [10, 10]

best_lecturer = Lecturer('Alex', 'Pit')

best_lecturer.grades = {
    'Python': [7, 10, 10, 8]
}

norm_reviewer = Reviewer('James', 'Bound', 5)

print(norm_reviewer)

print(best_lecturer)

print(cool_student)
# Out:
# Имя: James
# Фамилия: Bound
# Имя: Alex
# Фамилия: Pit
# Средняя оценка за лекции: 8.75
# Имя: Rick
# Фамилия: David
# Средняя оценка за домашние задания: 6.4
# Курсы в процессе изучения: Python, Math
# Завершенные курсы: English

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
class Student:
    def __init__(self, name, surname, gender, students=0, homeworks=0):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        self.homeworks = homeworks

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)
    def add_finished_course(self, course_name):
      self.finished_courses.append(course_name)


    def rate_lecturer(self, lecturer, course, grade):
        if course in lecturer.grades:
            lecturer.grades[course].append(grade)
        else:
            lecturer.grades[course] = [grade]
        return f"Оценка {grade} поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}."

    def _avg_grade(self):
        if not self.grades:
            return 0
        all_grades = [g for grades in self.grades.values() for g in grades]
        return sum(all_grades) / len(all_grades)

    def __str__(self):
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {self._avg_grade():.1f}\n"
                f"Курсы в процессе изучения: {', '.join(self.courses_in_progress)}\n"
                f"Завершенные курсы: {', '.join(self.finished_courses)}")

    def __len__(self):
      return len(self.courses_in_progress) + len(self.finished_courses)




class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

class Lecturer(Mentor):
    def __init__(self, name, surname, students=0, lectures=0):
        super().__init__(name, surname)
        self.lectures = lectures
        self.courses_attached = []
        self.grades = {}

    def __str__(self):
      sum_grade = 0.0
      if self.grades:
          all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
          if all_grades:
              sum_grade = sum(all_grades) / len(all_grades)

      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Средняя оценка за лекции: {sum_grade}')


    def __len__(self):
        return len(self.courses_attached)

    def cyrse(self, course_name):
      if course_name in self.courses_attached:
        return('Да, лектор ведет этот курс')
      else:
        return('Нет, лектор не ведет этот курс')



class Reviewer(Mentor):
    def __init__(self, name, surname, homeworks=0):
        super().__init__(name, surname)
        self.homeworks = homeworks

    def rate_hw(self, student, course, gradest):
        if course in student.grades:
            student.grades[course].append(gradest)
        else:
            student.grades[course] = [gradest]
        return f"Оценка {gradest} успешно поставлена студенту {student.name} {student.surname} за домашнее задание по курсу {course}."

    def otchislenie(self, student, course, hw):
      self.hw = hw
      if self.hw < 5:
        return 'Необходимо сдать до завтра'
      else:
        return 'У вас все хорошо!'


    def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'

# %%
student = Student('Rick', 'David', 'Male')
student.courses_in_progress = ['Python', 'Math']
student.finished_courses = ['English']
student.grades = {
    'Python': [1,2,9],
    'Math': [10,10]
}

lecturer = Lecturer('Alex', 'Pit')
lecturer.courses_attached = ['Math', 'Phisic', 'Biology', 'IT']
lecturer.grades = {
    'Math': [8, 10, 10]
}

reviewer = Reviewer('James', 'Bound', 5)
reviewer.courses_attached = ['Python', 'Math']

# __str__
print(student)
print()
print(lecturer)
print()
print(reviewer)
print()

# __len__
print('Количество курсов у студента:', len(student))
print('Количество курсов, которые ведет лектор:', len(lecturer))

# __contains__
print(lecturer.cyrse('Math'))
# Out:
# Имя: Rick
# Фамилия: David
# Средняя оценка за домашние задания: 6.4
# Курсы в процессе изучения: Python, Math
# Завершенные курсы: English
#
# Имя: Alex
# Фамилия: Pit
# Средняя оценка за лекции: 9.333333333333334
#
# Имя: James
# Фамилия: Bound
#
# Количество курсов у студента: 3
# Количество курсов, которые ведет лектор: 4
# Да, лектор ведет этот курс

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
class Student:
    def __init__(self, name, surname, gender, students=0, homeworks=0):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}
        self.homeworks = homeworks

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)
    def add_finished_course(self, course_name):
      self.finished_courses.append(course_name)

    def sr_grade(self):
      if not self.grades:
          return 0.0
      all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
      return sum(all_grades) / len(all_grades) if all_grades else 0.0


    def rate_lecturer(self, lecturer, course, grade):
        if course in lecturer.grades:
            lecturer.grades[course].append(grade)
        else:
            lecturer.grades[course] = [grade]
        return f"Оценка {grade} поставлена лектору {lecturer.name} {lecturer.surname} за курс {course}."

    def __str__(self):
        sum_grade = self.sr_grade()
        courses_in_progress_str = ', '.join(self.courses_in_progress) if self.courses_in_progress else 'Нет'
        finished_courses_str = ', '.join(self.finished_courses) if self.finished_courses else 'Нет'
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {sum_grade:.1f}\n"
                f'Курсы в процессе изучения: {courses_in_progress_str}\n'\
                f'Завершенные курсы: {finished_courses_str}')

    def __len__(self):
      return len(self.courses_in_progress) + len(self.finished_courses)




class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

class Lecturer(Mentor):
    def __init__(self, name, surname, students=0, lectures=0):
        super().__init__(name, surname)
        self.lectures = lectures
        self.courses_attached = []
        self.grades = {}

    def __str__(self):
      sum_grade = 0.0
      if self.grades:
          all_grades = [grade for grades_list in self.grades.values() for grade in grades_list]
          if all_grades:
              sum_grade = sum(all_grades) / len(all_grades)

      return (f'Имя: {self.name}\n'\
              f'Фамилия: {self.surname}\n'\
              f'Средняя оценка за лекции: {sum_grade}')

    def sr_lecture_grade(self):
      all_grades = [grade for grades_list in self.grades_for_lectures.values() for grade in grades_list]
      return sum(all_grades) / len(all_grades) if all_grades else 0.0


    def __len__(self):
        return len(self.courses_attached)

    def cyrse(self, course_name):
      if course_name in self.courses_attached:
        return(f'Да, лектор ведет курс {course_name}')
      else:
        return(f'Нет, лектор не ведет курс {course_name}')



class Reviewer(Mentor):
    def __init__(self, name, surname, homeworks=0):
        super().__init__(name, surname)
        self.homeworks = homeworks

    def rate_hw(self, student, course, gradest):
        if course in student.grades:
            student.grades[course].append(gradest)
        else:
            student.grades[course] = [gradest]
        return f"Оценка {gradest} успешно поставлена студенту {student.name} {student.surname} за домашнее задание по курсу {course}."

    def otchislenie(self, student, course = 0, hw = 0):
      self.hw = hw
      if self.hw < 5:
        return 'Необходимо сдать до завтра'
      else:
        return 'У вас все хорошо!'


    def __str__(self):
      return f'Имя: {self.name}\nФамилия: {self.surname}'

# %%
student1 = Student('Alex', 'Pit', 'male')
student2 = Student('Alice', 'Dip', 'female')

lecturer1 = Lecturer('Dirtir', 'Chit', students=5)
lecturer2 = Lecturer('Pirtir', 'Krit', students=7)

reviewer1 = Reviewer('Old', 'Man', homeworks=10)
reviewer2 = Reviewer('Tril', 'Make', homeworks=15)


student1.courses_in_progress = ['Python', 'Math', 'Geography']
student2.courses_in_progress = ['Python']

student1.add_finished_course('English')
student2.add_finished_course('Russian')

lecturer1.courses_attached = ['Python', 'Math']
lecturer2.courses_attached = ['Math']

reviewer1.courses_attached = ['Python']
reviewer2.courses_attached = ['Math']


print(reviewer1.rate_hw(student1, 'Python', 9))
print(reviewer1.rate_hw(student1, 'Math', 9))
print(reviewer1.rate_hw(student2, 'Python', 10))
print(reviewer2.rate_hw(student1, 'Math', 8))
print()


lecturer1.grades_for_lectures = {}
lecturer2.grades_for_lectures = {}

print(student1.rate_lecturer(lecturer1, 'Python', 10))
print(student1.rate_lecturer(lecturer1, 'Math', 2))
print(student2.rate_lecturer(lecturer2, 'Math', 10))
print(student2.rate_lecturer(lecturer1, 'Python', 9))
print(student1.rate_lecturer(lecturer2, 'Math', 7))
print()


print(student1)
print()
print(student2)
print()
print(lecturer1)
print()
print(lecturer2)
print()
print(reviewer1)
print()
print(reviewer2)

print()


print('Количество курсов(всех) у студента1:', len(student1))
print('Количество курсов(всех) у студента2:', len(student2))
print()


print('Количество курсов, которые ведет лектор1:', len(lecturer1))
print('Количество курсов, которые ведет лектор2:', len(lecturer2))

print()

print('\nПроверка метода otchislenie():')
print('Студент 1:', reviewer1.otchislenie(student1, 'Math', 4))
print('Студент 2:', reviewer2.otchislenie(student2, 'Python', 8))
print()

print('Ведет ли лектор1 курс:',lecturer1.cyrse('Math'))
print('Ведет ли лектор2 курс:',lecturer2.cyrse('Math'))
print('Ведет ли лектор1 курс:',lecturer1.cyrse('Geography'))
print('Ведет ли лектор2 курс:',lecturer2.cyrse('Python'))
print('Ведет ли лектор1 курс:',lecturer1.cyrse('Python'))
# Out:
# Оценка 9 успешно поставлена студенту Alex Pit за домашнее задание по курсу Python.
# Оценка 9 успешно поставлена студенту Alex Pit за домашнее задание по курсу Math.
# Оценка 10 успешно поставлена студенту Alice Dip за домашнее задание по курсу Python.
# Оценка 8 успешно поставлена студенту Alex Pit за домашнее задание по курсу Math.
#
# Оценка 10 поставлена лектору Dirtir Chit за курс Python.
# Оценка 2 поставлена лектору Dirtir Chit за курс Math.
# Оценка 10 поставлена лектору Pirtir Krit за курс Math.
# Оценка 9 поставлена лектору Dirtir Chit за курс Python.
# Оценка 7 поставлена лектору Pirtir Krit за курс Math.
#
# Имя: Alex
# Фамилия: Pit
# Средняя оценка за домашние задания: 8.7
# Курсы в процессе изучения: Python, Math, Geography
# Завершенные курсы: English
#
# Имя: Alice
# Фамилия: Dip
# Средняя оценка за домашние задания: 10.0
# Курсы в процессе изучения: Python
# Завершенные курсы: Russian
#
# Имя: Dirtir
# Фамилия: Chit
# Средняя оценка за лекции: 7.0
#
# Имя: Pirtir
# ...

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
class Fraction:
  def __init__(self, chislitel, znamenatel):
    self.chislitel = chislitel
    self.znamenatel = znamenatel
    self.simply()

    if znamenatel == 0:
      raise ValueError('Знаменатель не может быть нулем')

    if not isinstance(chislitel, int) or not isinstance(znamenatel, int):
            raise ValueError("Числитель и знаменатель должны быть целыми числами")


  def nod(self, a, b):
    while b != 0:
        a, b = b, a % b
    return abs(a)

  def simply(self):
    if self.znamenatel < 0:
      self.chislitel = -self.chislitel
      self.znamenatel = -self.znamenatel

    nod = self.nod(self.chislitel, self.znamenatel)
    self.chislitel //= nod
    self.znamenatel //= nod

  def __add__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    chisl = self.chislitel * other.znamenatel + other.chislitel * self.znamenatel
    znam = self.znamenatel * other.znamenatel
    return Fraction(chisl, znam)

  def __sub__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    chisl = self.chislitel * other.znamenatel - other.chislitel * self.znamenatel
    znam = self.znamenatel * other.znamenatel
    return Fraction(chisl, znam)

  def __mul__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    chisl = self.chislitel * other.chislitel
    znam = self.znamenatel * other.znamenatel
    return Fraction(chisl, znam)

  def __truediv__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    if other.chislitel == 0:
        raise ZeroDivisionError("Деление на нулевую дробь невозможно")
    chisl = self.chislitel * other.znamenatel
    znam = self.znamenatel * other.chislitel
    return Fraction(chisl, znam)

  def __eq__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    d1 = Fraction(self.chislitel, self.znamenatel)
    d2 = Fraction(other.chislitel, other.znamenatel)
    return d1.chislitel == d2.chislitel and d1.znamenatel == d2.znamenatel
  def __lt__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    return self.chislitel * other.znamenatel < other.chislitel * self.znamenatel

  def __le__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    return self.chislitel * other.znamenatel <= other.chislitel * self.znamenatel

  def __gt__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    return self.chislitel * other.znamenatel > other.chislitel * self.znamenatel

  def __ge__(self, other):
    if not isinstance(other, Fraction):
        return NotImplemented
    return self.chislitel * other.znamenatel >= other.chislitel * self.znamenatel

  def __float__(self):
    return self.chislitel/self.znamenatel

  def reciprocal(self):
    if self.chislitel == 0:
      raise ZeroDivisionError('Нельзя получить обратную дробь для нуля')
    return Fraction(self.znamenatel, self.chislitel)

  def __str__(self):
    if self.znamenatel==1:
      return str(self.chislitel)
    return f"{self.chislitel}/{self.znamenatel}"

  def __repr__(self):
    return f"Fraction({self.chislitel}, {self.znamenatel})"

  @classmethod
  def from_float(cls, value):
    from math import gcd
    znamenatel = 100000
    chislitel = int(value*znamenatel)
    c = gcd(chislitel, znamenatel)
    return cls(chislitel // c, znamenatel // c)

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
print(f1)
f2 = Fraction(5, 6)
print(f2)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
# Out:
# 3/4
# 5/6
# 19/12
# -1/12
# 5/8
# 9/10
# True
# False
# True
# 0.75
# 4/3
# 3/4
# Знаменатель не может быть нулем
# 3/4
# Fraction(3, 4)
